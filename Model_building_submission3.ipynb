# %% [markdown]
# # Machine Learning Model building:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv('X_train.csv', index_col = 0)
y_train = pd.read_csv('y_train.csv', index_col = 0)

X_test = pd.read_csv('X_test.csv', index_col = 0)
y_test = pd.read_csv('y_test.csv', index_col = 0)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1185, 95), (1185, 1), (509, 95), (509, 1))

# %%
X_train.head()
# Out:
#    InscClaimAmtReimbursed_x  DeductibleAmtPaid_x  InpatientClaimPeriod  \
# 0                  0.374106             0.397022              0.602522
# 1                 -0.466088            -0.392396             -0.225617
# 2                  1.394224             1.581149              0.766224
# 3                 -0.671322            -0.674331             -0.755240
# 4                 -0.819883            -0.787105             -0.813018
#
#    DurationInHospital  NoOfMonths_PartACov_x  NoOfMonths_PartBCov_x  \
# 0            0.604925               0.437071               0.399336
# 1           -0.225377              -0.344025              -0.345599
# 2            0.769055               1.552923               1.420172
# 3           -0.756384              -0.678781              -0.676681
# 4           -0.814312              -0.790366              -0.787042
#
#    IPAnnualReimbursementAmt_x  IPAnnualDeductibleAmt_x  \
# 0                    0.359046                 0.369976
# 1                   -0.582854                -0.429459
# 2                    1.126207                 1.260807
# 3                   -0.721075                -0.711746
# 4                   -0.801993                -0.775377
#
#    OPAnnualReimbursementAmt_x  OPAnnualDeductibleAmt_x  ...  \
# 0                    0.106610                -0.259113  ...
# 1                   -0.622873                -0.647265  ...
# 2                    0.670751                 0.303250  ...
# 3                   -0.738229                -0.571876  ...
# 4                   -0.781075                -0.758312  ...
#
#    ChronicCond_Heartfailure_y  ChronicCond_KidneyDisease_y  \
# 0                   -0.454031                    -0.454031
# 1                   -0.032232                    -0.032232
# 2                   -0.100631                    -0.100631
# 3                   -0.237431                    -0.237431
# 4                   -0.944230                    -0.944230
#
#    ChronicCond_Cancer_y  ChronicCond_ObstrPulmonary_y  \
# 0             -0.454031                     -0.454031
# 1             -0.032232                     -0.032232
# 2             -0.100631                     -0.100631
# 3             -0.237431                     -0.237431
# 4             -0.944230                     -0.944230
#
#    ChronicCond_Depression_y  ChronicCond_Diabetes_y  \
# 0                 -0.454031               -0.454031
# 1                 -0.032232               -0.032232
# 2                 -0.100631               -0.100631
# 3                 -0.237431               -0.237431
# 4                 -0.944230               -0.944230
#
#    ChronicCond_IschemicHeart_y  ChronicCond_Osteoporasis_y  \
# 0                    -0.454031                   -0.454031
# 1                    -0.032232                   -0.032232
# 2                    -0.100631                   -0.100631
# 3                    -0.237431                   -0.237431
# 4                    -0.944230                   -0.944230
#
#    ChronicCond_rheumatoidarthritis_y  ChronicCond_stroke_y
# 0                          -0.454031             -0.454031
# 1                          -0.032232             -0.032232
# 2                          -0.100631             -0.100631
# 3                          -0.237431             -0.237431
# 4                          -0.944230             -0.944230
#
# [5 rows x 95 columns]

# %%
y_train.head()
# Out:
#    PotentialFraud
# 0               1
# 1               0
# 2               1
# 3               0
# 4               0

# %%
#y_train.shape

# %%
X_test.head()
# Out:
#    InscClaimAmtReimbursed_x  DeductibleAmtPaid_x  InpatientClaimPeriod  \
# 0                  0.143012             0.002313             -0.061915
# 1                  0.820889             0.848118              0.795112
# 2                 -0.044065            -0.054074             -0.004138
# 3                 -0.748354            -0.730718             -0.678204
# 4                  1.782684             1.524762              1.729176
#
#    DurationInHospital  NoOfMonths_PartACov_x  NoOfMonths_PartBCov_x  \
# 0           -0.061247              -0.009270              -0.014517
# 1            0.798019               0.883412               0.813188
# 2           -0.003319              -0.065062              -0.014517
# 3           -0.679147              -0.734574              -0.731861
# 4            1.734522               1.664508               1.640893
#
#    IPAnnualReimbursementAmt_x  IPAnnualDeductibleAmt_x  \
# 0                   -0.089625                -0.170885
# 1                    0.760329                 1.174894
# 2                   -0.099223                -0.170885
# 3                   -0.802438                -0.775377
# 4                    1.508135                 1.228992
#
#    OPAnnualReimbursementAmt_x  OPAnnualDeductibleAmt_x  ...  \
# 0                   -0.374585                -0.561688  ...
# 1                    0.144512                 0.204429  ...
# 2                   -0.628641                -0.637078  ...
# 3                   -0.776955                -0.763406  ...
# 4                    0.905581                 0.601751  ...
#
#    ChronicCond_Heartfailure_y  ChronicCond_KidneyDisease_y  \
# 0                   -0.499631                    -0.499631
# 1                    0.081768                     0.081768
# 2                    0.628967                     0.628967
# 3                   -0.009432                    -0.009432
# 4                    0.024768                     0.024768
#
#    ChronicCond_Cancer_y  ChronicCond_ObstrPulmonary_y  \
# 0             -0.499631                     -0.499631
# 1              0.081768                      0.081768
# 2              0.628967                      0.628967
# 3             -0.009432                     -0.009432
# 4              0.024768                      0.024768
#
#    ChronicCond_Depression_y  ChronicCond_Diabetes_y  \
# 0                 -0.499631               -0.499631
# 1                  0.081768                0.081768
# 2                  0.628967                0.628967
# 3                 -0.009432               -0.009432
# 4                  0.024768                0.024768
#
#    ChronicCond_IschemicHeart_y  ChronicCond_Osteoporasis_y  \
# 0                    -0.499631                   -0.499631
# 1                     0.081768                    0.081768
# 2                     0.628967                    0.628967
# 3                    -0.009432                   -0.009432
# 4                     0.024768                    0.024768
#
#    ChronicCond_rheumatoidarthritis_y  ChronicCond_stroke_y
# 0                          -0.499631             -0.499631
# 1                           0.081768              0.081768
# 2                           0.628967              0.628967
# 3                          -0.009432             -0.009432
# 4                           0.024768              0.024768
#
# [5 rows x 95 columns]

# %%
y_test.head()
# Out:
#    PotentialFraud
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver = 'liblinear', random_state = 42) 
# Changed the solver from 'lbfgs' to 'liblinear' and the error message "Str object has no attribute decode" solved.

# %%
y_train = y_train.values.ravel()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=42, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Let us apply this to test set
y_predict = lr.predict(X_test)

# %% [markdown]
# # Evaluate the ML model

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("classification_report:\n", classification_report(y_test, y_predict, labels = [1, 0]))
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            1       0.76      0.48      0.59       123
#            0       0.85      0.95      0.90       386
#
#     accuracy                           0.84       509
#    macro avg       0.80      0.72      0.74       509
# weighted avg       0.83      0.84      0.82       509
